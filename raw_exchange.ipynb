# %% [markdown]
# Parse the raw event log to compare CPU and GPU exchange operations.

# %%
import json
import os
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import HuberRegressor

cpu_profile_dirs = ["/opt/data/profiles/dataproc-cpu-sf100",
                    "/opt/data/profiles/dataproc-cpu-sf3k",
                    "/opt/data/profiles/dataproc-cpu-sf5k",
                    "/opt/data/profiles/dataproc-cpu-sf10k"]
gpu_profile_dirs = ["/opt/data/profiles/dataproc-gpu-sf100",
                    "/opt/data/profiles/dataproc-gpu-sf3k",
                    "/opt/data/profiles/dataproc-gpu-sf5k",
                    "/opt/data/profiles/dataproc-gpu-sf10k"]
cpu_event_dirs = ["/opt/data/events/dataproc-cpu-sf100",
                  "/opt/data/events/dataproc-cpu-sf3k",
                  "/opt/data/events/dataproc-cpu-sf5k",
                  "/opt/data/events/dataproc-cpu-sf10k"]
gpu_event_dirs = ["/opt/data/events/dataproc-gpu-sf100",
                  "/opt/data/events/dataproc-gpu-sf3k",
                  "/opt/data/events/dataproc-gpu-sf5k",
                  "/opt/data/events/dataproc-gpu-sf10k"]
scale_factors = ["100", "3K", "5K", "10K"]

# %%
class Exchange:
    def __init__(self, group=None):
        self.data_size = 0
        self.shuffle_bytes_written = 0
        self.shuffle_records_written = 0
        self.shuffle_write_time = 0
        self.accumulator_id = 0
        if group is None:
            return
        for row in group.itertuples():
            if row.name == "data size":
                self.data_size = row.total
            elif row.name == "shuffle bytes written":
                self.shuffle_bytes_written = row.total
            elif row.name == "shuffle records written":
                self.shuffle_records_written = row.total
            elif row.name == "shuffle write time":
                self.shuffle_write_time = row.total
                self.accumulator_id = row.accumulatorId

    def __eq__(self, other):
        if isinstance(other, Exchange):
            return (self.data_size == 0 or other.data_size == 0 or self.data_size == other.data_size) and \
                (self.shuffle_bytes_written == 0 or other.shuffle_bytes_written == 0 or
                 self.shuffle_bytes_written == other.shuffle_bytes_written) and \
                (self.shuffle_records_written == 0 or other.shuffle_records_written == 0 or
                 self.shuffle_records_written == other.shuffle_records_written) and \
                (self.shuffle_write_time == 0 or other.shuffle_write_time == 0 or
                    self.shuffle_write_time == other.shuffle_write_time)
        return False
    
    def __hash__(self):
        return hash((self.data_size, self.shuffle_bytes_written, self.shuffle_records_written, self.shuffle_write_time))

    def __str__(self):
        return f"{self.data_size}, {self.shuffle_bytes_written}, {self.shuffle_records_written}, {self.shuffle_write_time}"


def collect(node, exchange_list, exchange_set, exchange_map):
    if node['nodeName'] == 'Exchange' or node['nodeName'] == 'GpuColumnarExchange':
        for m in node['metrics']:
            if m['name'] == 'shuffle write time':
                accumulator_id = m['accumulatorId']
                if accumulator_id in exchange_map:
                    exchange = exchange_map[accumulator_id]
                    if exchange not in exchange_set:
                        exchange_set.add(exchange)
                        exchange_list.append(exchange)
    for child in node['children']:
        collect(child, exchange_list, exchange_set, exchange_map)


def collect_exchanges(profile_dir, event_file):
    sql_info = pd.read_csv(f"{profile_dir}/sql_plan_metrics_for_application.csv")
    condition = (sql_info['nodeName'] == 'Exchange') | (sql_info['nodeName'] == 'GpuColumnarExchange')
    filtered = sql_info[condition]
    grouped = filtered.groupby("nodeID")
    exchange_dict = {}
    for _, group in grouped:
        exchange = Exchange(group)
        if exchange.accumulator_id != 0:
            exchange_dict[exchange.accumulator_id] = exchange

    exchanges = []
    exchanges_set = set()
    with open(event_file, "r") as f:
        for line in f:
            event = json.loads(line)
            if "sparkPlanInfo" in event:
                exchanges.clear()
                collect(event["sparkPlanInfo"], exchanges, exchanges_set, exchange_dict)
    return sorted(exchanges, key=lambda e: (e.data_size, e.shuffle_bytes_written, e.shuffle_records_written))

num_scale_factors = len(scale_factors)
cpu_times = [[] for _ in range(num_scale_factors)]
gpu_times = [[] for _ in range(num_scale_factors)]
cpu_query_times = [[] for _ in range(num_scale_factors)]
gpu_query_times = [[] for _ in range(num_scale_factors)]
for i in range(num_scale_factors):
    cpu_profiles = os.listdir(cpu_profile_dirs[i])
    cpu_profiles.sort()
    num_apps = len(cpu_profiles)
    gpu_profiles = os.listdir(gpu_profile_dirs[i])
    gpu_profiles.sort()
    cpu_events = os.listdir(cpu_event_dirs[i])
    cpu_events.sort()
    gpu_events = os.listdir(gpu_event_dirs[i])
    gpu_events.sort()
    assert num_apps == len(gpu_profiles) == len(cpu_events) == len(gpu_events)
    for j in range(num_apps):
        print(f"Processing cpu profile {cpu_profiles[j]}, event file {cpu_events[j]}")
        cpu_exchanges = collect_exchanges(f"{cpu_profile_dirs[i]}/{cpu_profiles[j]}", f"{cpu_event_dirs[i]}/{cpu_events[j]}")
        print(f"Processing gpu profile {gpu_profiles[j]}, event file {gpu_events[j]}")
        gpu_exchanges = collect_exchanges(f"{gpu_profile_dirs[i]}/{gpu_profiles[j]}", f"{gpu_event_dirs[i]}/{gpu_events[j]}")
        if len(cpu_exchanges) != len(gpu_exchanges):
            print(f"Warning: cpu and gpu exchanges are of different length: {len(cpu_exchanges)} vs {len(gpu_exchanges)}")
        common_len = min(len(cpu_exchanges), len(gpu_exchanges))
        if len(cpu_exchanges) > common_len:
            cpu_exchanges = random.sample(cpu_exchanges, common_len)
        if len(gpu_exchanges) > common_len:
            gpu_exchanges = random.sample(gpu_exchanges, common_len)
        cpu_times[i].extend(e.shuffle_write_time for e in cpu_exchanges)
        gpu_times[i].extend(e.shuffle_write_time for e in gpu_exchanges)
        cpu_query_times[i].append(sum(e.shuffle_write_time for e in cpu_exchanges))
        gpu_query_times[i].append(sum(e.shuffle_write_time for e in gpu_exchanges))
# Out:
# Processing cpu profile application_1702070228385_0149, event file eventlog-cpu-sf100-query01
# Processing gpu profile application_1702268529525_0404, event file eventlog-gpu-sf100-query01
# Warning: cpu and gpu exchanges are of different length: 4 vs 5
# Processing cpu profile application_1702070228385_0150, event file eventlog-cpu-sf100-query02
# Processing gpu profile application_1702268529525_0405, event file eventlog-gpu-sf100-query02
# Processing cpu profile application_1702070228385_0151, event file eventlog-cpu-sf100-query03
# Processing gpu profile application_1702268529525_0406, event file eventlog-gpu-sf100-query03
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0152, event file eventlog-cpu-sf100-query04
# Processing gpu profile application_1702268529525_0407, event file eventlog-gpu-sf100-query04
# Warning: cpu and gpu exchanges are of different length: 12 vs 20
# Processing cpu profile application_1702070228385_0153, event file eventlog-cpu-sf100-query05
# Processing gpu profile application_1702268529525_0408, event file eventlog-gpu-sf100-query05
# Warning: cpu and gpu exchanges are of different length: 4 vs 7
# Processing cpu profile application_1702070228385_0154, event file eventlog-cpu-sf100-query06
# Processing gpu profile application_1702268529525_0409, event file eventlog-gpu-sf100-query06
# Warning: cpu and gpu exchanges are of different length: 7 vs 8
# Processing cpu profile application_1702070228385_0155, event file eventlog-cpu-sf100-query07
# Processing gpu profile application_1702268529525_0410, event file eventlog-gpu-sf100-query07
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0156, event file eventlog-cpu-sf100-query08
# Processing gpu profile application_1702268529525_0411, event file eventlog-gpu-sf100-query08
# Warning: cpu and gpu exchanges are of different length: 5 vs 6
# Processing cpu profile application_1702070228385_0157, event file eventlog-cpu-sf100-query09
# Processing gpu profile application_1702268529525_0412, event file eventlog-gpu-sf100-query09
# Processing cpu profile application_1702070228385_0158, event file eventlog-cpu-sf100-query10
# Processing gpu profile application_1702268529525_0413, event file eventlog-gpu-sf100-query10
# Warning: cpu and gpu exchanges are of different length: 5 vs 6
# Processing cpu profile application_1702070228385_0159, event file eventlog-cpu-sf100-query11
# Processing gpu profile application_1702268529525_0414, event file eventlog-gpu-sf100-query11
# Warning: cpu and gpu exchanges are of different length: 8 vs 14
# Processing cpu profile application_1702070228385_0160, event file eventlog-cpu-sf100-query12
# Processing gpu profile application_1702268529525_0415, event file eventlog-gpu-sf100-query12
# Warning: cpu and gpu exchanges are of different length: 2 vs 3
# Processing cpu profile application_1702070228385_0161, event file eventlog-cpu-sf100-query13
# Processing gpu profile application_1702268529525_0416, event file eventlog-gpu-sf100-query13
# Processing cpu profile application_1702070228385_0162, event file eventlog-cpu-sf100-query14_part1
# Processing gpu profile application_1702268529525_0417, event file eventlog-gpu-sf100-query14_part1
# Warning: cpu and gpu exchanges are of different length: 12 vs 18
# Processing cpu profile application_1702070228385_0163, event file eventlog-cpu-sf100-query14_part2
# Processing gpu profile application_1702268529525_0418, event file eventlog-gpu-sf100-query14_part2
# Warning: cpu and gpu exchanges are of different length: 10 vs 16
# Processing cpu profile application_1702070228385_0164, event file eventlog-cpu-sf100-query15
# Processing gpu profile application_1702268529525_0419, event file eventlog-gpu-sf100-query15
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0165, event file eventlog-cpu-sf100-query16
# Processing gpu profile application_1702268529525_0420, event file eventlog-gpu-sf100-query16
# Processing cpu profile application_1702070228385_0166, event file eventlog-cpu-sf100-query17
# Processing gpu profile application_1702268529525_0421, event file eventlog-gpu-sf100-query17
# Warning: cpu and gpu exchanges are of different length: 5 vs 6
# Processing cpu profile application_1702070228385_0167, event file eventlog-cpu-sf100-query18
# Processing gpu profile application_1702268529525_0422, event file eventlog-gpu-sf100-query18
# Warning: cpu and gpu exchanges are of different length: 1 vs 4
# Processing cpu profile application_1702070228385_0168, event file eventlog-cpu-sf100-query19
# Processing gpu profile application_1702268529525_0423, event file eventlog-gpu-sf100-query19
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0169, event file eventlog-cpu-sf100-query20
# Processing gpu profile application_1702268529525_0424, event file eventlog-gpu-sf100-query20
# Warning: cpu and gpu exchanges are of different length: 2 vs 3
# Processing cpu profile application_1702070228385_0170, event file eventlog-cpu-sf100-query21
# Processing gpu profile application_1702268529525_0425, event file eventlog-gpu-sf100-query21
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0171, event file eventlog-cpu-sf100-query22
# Processing gpu profile application_1702268529525_0426, event file eventlog-gpu-sf100-query22
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0172, event file eventlog-cpu-sf100-query23_part1
# Processing gpu profile application_1702268529525_0427, event file eventlog-gpu-sf100-query23_part1
# Processing cpu profile application_1702070228385_0173, event file eventlog-cpu-sf100-query23_part2
# Processing gpu profile application_1702268529525_0428, event file eventlog-gpu-sf100-query23_part2
# Warning: cpu and gpu exchanges are of different length: 12 vs 13
# Processing cpu profile application_1702070228385_0174, event file eventlog-cpu-sf100-query24_part1
# Processing gpu profile application_1702268529525_0429, event file eventlog-gpu-sf100-query24_part1
# Warning: cpu and gpu exchanges are of different length: 2 vs 3
# Processing cpu profile application_1702070228385_0175, event file eventlog-cpu-sf100-query24_part2
# Processing gpu profile application_1702268529525_0430, event file eventlog-gpu-sf100-query24_part2
# Warning: cpu and gpu exchanges are of different length: 2 vs 3
# Processing cpu profile application_1702070228385_0176, event file eventlog-cpu-sf100-query25
# Processing gpu profile application_1702268529525_0431, event file eventlog-gpu-sf100-query25
# Warning: cpu and gpu exchanges are of different length: 5 vs 6
# Processing cpu profile application_1702070228385_0177, event file eventlog-cpu-sf100-query26
# Processing gpu profile application_1702268529525_0432, event file eventlog-gpu-sf100-query26
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0178, event file eventlog-cpu-sf100-query27
# Processing gpu profile application_1702268529525_0433, event file eventlog-gpu-sf100-query27
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0179, event file eventlog-cpu-sf100-query28
# Processing gpu profile application_1702268529525_0434, event file eventlog-gpu-sf100-query28
# Processing cpu profile application_1702070228385_0180, event file eventlog-cpu-sf100-query29
# Processing gpu profile application_1702268529525_0435, event file eventlog-gpu-sf100-query29
# Warning: cpu and gpu exchanges are of different length: 5 vs 6
# Processing cpu profile application_1702070228385_0181, event file eventlog-cpu-sf100-query30
# Processing gpu profile application_1702268529525_0436, event file eventlog-gpu-sf100-query30
# Warning: cpu and gpu exchanges are of different length: 4 vs 7
# Processing cpu profile application_1702070228385_0182, event file eventlog-cpu-sf100-query31
# Processing gpu profile application_1702268529525_0437, event file eventlog-gpu-sf100-query31
# Processing cpu profile application_1702070228385_0183, event file eventlog-cpu-sf100-query32
# Processing gpu profile application_1702268529525_0438, event file eventlog-gpu-sf100-query32
# Processing cpu profile application_1702070228385_0184, event file eventlog-cpu-sf100-query33
# Processing gpu profile application_1702268529525_0439, event file eventlog-gpu-sf100-query33
# Warning: cpu and gpu exchanges are of different length: 4 vs 5
# Processing cpu profile application_1702070228385_0185, event file eventlog-cpu-sf100-query34
# Processing gpu profile application_1702268529525_0440, event file eventlog-gpu-sf100-query34
# Warning: cpu and gpu exchanges are of different length: 0 vs 1
# Processing cpu profile application_1702070228385_0186, event file eventlog-cpu-sf100-query35
# Processing gpu profile application_1702268529525_0441, event file eventlog-gpu-sf100-query35
# Warning: cpu and gpu exchanges are of different length: 5 vs 6
# Processing cpu profile application_1702070228385_0187, event file eventlog-cpu-sf100-query36
# Processing gpu profile application_1702268529525_0442, event file eventlog-gpu-sf100-query36
# Warning: cpu and gpu exchanges are of different length: 2 vs 3
# Processing cpu profile application_1702070228385_0188, event file eventlog-cpu-sf100-query37
# Processing gpu profile application_1702268529525_0443, event file eventlog-gpu-sf100-query37
# Warning: cpu and gpu exchanges are of different length: 3 vs 4
# Processing cpu profile application_1702070228385_0189, event file eventlog-cpu-sf100-query38
# Processing gpu profile application_1702268529525_0444, event file eventlog-gpu-sf100-query38
# Warning: cpu and gpu exchanges are of different length: 10 vs 14
# Processing cpu profile application_1702070228385_0190, event file eventlog-cpu-sf100-query39_part1
# Processing gpu profile application_1702268529525_0445, event file eventlog-gpu-sf100-query39_part1
# Processing cpu profile application_1702070228385_0191, event file eventlog-cpu-sf100-query39_part2
# Processing gpu profile application_1702268529525_0446, event file eventlog-gpu-sf100-query39_part2
# Processing cpu profile application_1702070228385_0192, event file eventlog-cpu-sf100-query40
# Processing gpu profile application_1702268529525_0447, event file eventlog-gpu-sf100-query40
# Warning: cpu and gpu exchanges are of different length: 1 vs 4
# Processing cpu profile application_1702070228385_0193, event file eventlog-cpu-sf100-query41
# Processing gpu profile application_1702268529525_0448, event file eventlog-gpu-sf100-query41
# Warning: cpu and gpu exchanges are of different length: 0 vs 1
# Processing cpu profile application_1702070228385_0194, event file eventlog-cpu-sf100-query42
# Processing gpu profile application_1702268529525_0449, event file eventlog-gpu-sf100-query42
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0195, event file eventlog-cpu-sf100-query43
# Processing gpu profile application_1702268529525_0450, event file eventlog-gpu-sf100-query43
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0196, event file eventlog-cpu-sf100-query44
# Processing gpu profile application_1702268529525_0451, event file eventlog-gpu-sf100-query44
# Processing cpu profile application_1702070228385_0197, event file eventlog-cpu-sf100-query45
# Processing gpu profile application_1702268529525_0452, event file eventlog-gpu-sf100-query45
# Warning: cpu and gpu exchanges are of different length: 1 vs 2
# Processing cpu profile application_1702070228385_0198, event file eventlog-cpu-sf100-query46
# Processing gpu profile application_1702268529525_0453, event file eventlog-gpu-sf100-query46
# Warning: cpu and gpu exchanges are of different length: 1 vs 4
# Processing cpu profile application_1702070228385_0199, event file eventlog-cpu-sf100-query47
# Processing gpu profile application_1702268529525_0454, event file eventlog-gpu-sf100-query47

# %%
for i in range(num_scale_factors):
    plt.scatter(cpu_times[i], gpu_times[i])
    plt.xscale('log')
    plt.yscale('log')
    
    # Adding title and labels (optional)
    plt.title(f"Exchange Shuffle Write Times - SF{scale_factors[i]}")
    plt.xlabel("CPU")
    plt.ylabel("GPU")
    
    # Show the plot
    plt.show()

# %%
for i in range(num_scale_factors):
    plt.scatter(cpu_times[i], gpu_times[i], label=f"SF{scale_factors[i]}")

plt.xscale('log')
plt.yscale('log')
plt.title("Exchange Shuffle Write Times - Combined")
plt.xlabel("CPU")
plt.ylabel("GPU")
plt.legend()

# Show the plot
plt.show()
